# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # 1. Data Ingestion

# %%
df =pd.read_csv('weather_data.csv')
df
# Out:
#           date      city  temperature_celsius  humidity_percent  \
# 0   2023-01-01  New York                  5.0              60.0
# 1   01/02/2023  New York                  NaN              65.0
# 2   03-01-2023  New York                  7.0               NaN
# 3          NaN    London                  8.0              70.0
# 4   2023-01-02    London                  6.0              75.0
# ..         ...       ...                  ...               ...
# 95  01-01-2023    London                  NaN               NaN
# 96  09-01-2023    London                  NaN               NaN
# 97  2023-01-11     Tokyo                  NaN               NaN
# 98  15/01/2023  New York                  NaN              41.0
# 99  01/12/2023    London                 13.7              41.0
#
#     wind_speed_kph weather_condition
# 0             10.0             Sunny
# 1             12.0            Cloudy
# 2              8.0             Rainy
# 3             15.0           Unknown
# 4             20.0             Snowy
# ..             ...               ...
# 95             NaN             Rainy
# 96             NaN             Rainy
# 97             NaN             Sunny
# 98            24.3               NaN
# 99             NaN           Unknown
#
# [100 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# date                   20
# city                    0
# temperature_celsius    58
# humidity_percent       53
# wind_speed_kph         45
# weather_condition      16
# dtype: int64

# %% [markdown]
# # 2.Data Cleaning and Trnsformation

# %%
from sklearn.impute import SimpleImputer

# %%
numerical_cols = df.select_dtypes(include = ['number']).columns
print('Numerical columns:', numerical_cols.tolist())
# Out:
# Numerical columns: ['temperature_celsius', 'humidity_percent', 'wind_speed_kph', 'temperature_fahrenheit']

# %%
catagorical_cols = df.select_dtypes(include=['object']).columns
print('Catagorical Columns:', catagorical_cols.tolist())
# Out:
# Catagorical Columns: ['date', 'city', 'weather_condition']

# %%
imputer_1 = SimpleImputer(strategy ='mean')
df[numerical_cols] = imputer_1.fit_transform(df[numerical_cols])
imputer_2 = SimpleImputer(strategy = 'most_frequent')
df[catagorical_cols] = imputer_2.fit_transform(df[catagorical_cols])
df
# Out:
#           date      city  temperature_celsius  humidity_percent  \
# 0   01-01-2023  New York                  5.0         60.000000
# 1   01-02-2023  New York                  8.4         65.000000
# 2   03-01-2023  New York                  7.0         58.978723
# 3   14-01-2023    London                  8.0         70.000000
# 4   02-01-2023    London                  6.0         75.000000
# ..         ...       ...                  ...               ...
# 95  01-01-2023    London                  8.4         58.978723
# 96  09-01-2023    London                  8.4         58.978723
# 97  11-01-2023     Tokyo                  8.4         58.978723
# 98  15-01-2023  New York                  8.4         41.000000
# 99  01-12-2023    London                 13.7         41.000000
#
#     wind_speed_kph weather_condition  temperature_fahrenheit
# 0        10.000000             sunny                   41.00
# 1        12.000000            cloudy                   47.12
# 2         8.000000             rainy                   44.60
# 3        15.000000           unknown                   46.40
# 4        20.000000             snowy                   42.80
# ..             ...               ...                     ...
# 95       14.352727             rainy                   47.12
# 96       14.352727             rainy                   47.12
# 97       14.352727             sunny                   47.12
# 98       24.300000           unknown                   47.12
# 99       14.352727           unknown                   56.66
#
# [100 rows x 7 columns]

# %%
df['temperature_fahrenheit'] = df['temperature_celsius'] * 9 / 5 + 32
df
# Out:
#           date      city  temperature_celsius  humidity_percent  \
# 0   01-01-2023  New York                  5.0         60.000000
# 1   01-02-2023  New York                  8.4         65.000000
# 2   03-01-2023  New York                  7.0         58.978723
# 3   14-01-2023    London                  8.0         70.000000
# 4   02-01-2023    London                  6.0         75.000000
# ..         ...       ...                  ...               ...
# 95  01-01-2023    London                  8.4         58.978723
# 96  09-01-2023    London                  8.4         58.978723
# 97  11-01-2023     Tokyo                  8.4         58.978723
# 98  15-01-2023  New York                  8.4         41.000000
# 99  01-12-2023    London                 13.7         41.000000
#
#     wind_speed_kph weather_condition  temperature_fahrenheit
# 0        10.000000             sunny                   41.00
# 1        12.000000            cloudy                   47.12
# 2         8.000000             rainy                   44.60
# 3        15.000000           unknown                   46.40
# 4        20.000000             snowy                   42.80
# ..             ...               ...                     ...
# 95       14.352727             rainy                   47.12
# 96       14.352727             rainy                   47.12
# 97       14.352727             sunny                   47.12
# 98       24.300000           unknown                   47.12
# 99       14.352727           unknown                   56.66
#
# [100 rows x 7 columns]

# %%
df['date'] = pd.to_datetime(df['date'], dayfirst=True, errors='coerce')
df['date'] = df['date'].dt.strftime('%y-%m-%d')
df
# Out:
#         date      city  temperature_celsius  humidity_percent  wind_speed_kph  \
# 0   23-01-01  New York                  5.0         60.000000       10.000000
# 1   23-02-01  New York                  8.4         65.000000       12.000000
# 2   23-01-03  New York                  7.0         58.978723        8.000000
# 3   23-01-14    London                  8.0         70.000000       15.000000
# 4   23-01-02    London                  6.0         75.000000       20.000000
# ..       ...       ...                  ...               ...             ...
# 95  23-01-01    London                  8.4         58.978723       14.352727
# 96  23-01-09    London                  8.4         58.978723       14.352727
# 97  23-01-11     Tokyo                  8.4         58.978723       14.352727
# 98  23-01-15  New York                  8.4         41.000000       24.300000
# 99  23-12-01    London                 13.7         41.000000       14.352727
#
#    weather_condition  temperature_fahrenheit
# 0              sunny                   41.00
# 1             cloudy                   47.12
# 2              rainy                   44.60
# 3            unknown                   46.40
# 4              snowy                   42.80
# ..               ...                     ...
# 95             rainy                   47.12
# 96             rainy                   47.12
# 97             sunny                   47.12
# 98           unknown                   47.12
# 99           unknown                   56.66
#
# [100 rows x 7 columns]

# %%
df = df[(df['weather_condition'].str.lower() != 'unknown')]

df
# Out:
#         date      city  temperature_celsius  humidity_percent  wind_speed_kph  \
# 0   23-01-01  New York                  5.0         60.000000       10.000000
# 1   23-02-01  New York                  8.4         65.000000       12.000000
# 2   23-01-03  New York                  7.0         58.978723        8.000000
# 4   23-01-02    London                  6.0         75.000000       20.000000
# 92  23-01-25    London                  8.4         58.978723       29.900000
# 95  23-01-01    London                  8.4         58.978723       14.352727
# 96  23-01-09    London                  8.4         58.978723       14.352727
# 97  23-01-11     Tokyo                  8.4         58.978723       14.352727
#
#    weather_condition  temperature_fahrenheit
# 0              sunny                   41.00
# 1             cloudy                   47.12
# 2              rainy                   44.60
# 4              snowy                   42.80
# 5             cloudy                   47.12
# 6              sunny                   50.00
# 7             cloudy                   53.60
# 9              sunny                   47.12
# 12             snowy                   47.12
# 14             rainy                   47.12
# 15             rainy                   47.12
# 16             rainy                   47.12
# 20             rainy                   43.16
# 21             rainy                   66.74
# 23             rainy                   47.12
# 26             sunny                   47.12
# 28             rainy                   47.12
# 29             sunny                   47.12
# 30            cloudy                   47.12
# 32             rainy                   27.14
# 33            cloudy                   47.12
# 34             sunny                   55.22
# 35             sunny                   47.12
# 36             rainy                   47.12
# 37             rainy                   47.12
# 41            cloudy                   50.36
# 43             rainy                   47.12
# 44             rainy                   47.12
# 46             snowy                   47.12
# 49             snowy                   38.12
# 50             rainy                   47.12
# 53             sunny                   47.12
# 55             snowy                   56.12
# 56             snowy                   38.12
# 58             snowy                   47.12
# 59            cloudy                   47.12
# 62            cloudy                   47.12
# 64             snowy                   64.58
# 66            cloudy                   48.74
# 67            cloudy                   47.12
# 68             snowy                   47.12
# 70             rainy                   53.96
# 72             rainy                   47.12
# 73             rainy                   42.44
# 76             rainy                   47.12
# 79            cloudy                   47.12
# 80             rainy                   25.34
# 82             rainy                   40.64
# 84            cloudy                   47.12
# 86            cloudy                   28.94
# 89             rainy                   47.12
# 92            cloudy                   47.12
# 95             rainy                   47.12
# 96             rainy                   47.12
# 97             sunny                   47.12

# %%
os.makedirs('outputs', exist_ok=True)
df.to_csv('outputs/transformed_weather_data.csv', index=False)

# %%
df.loc[:, 'temperature_celsius'] = pd.to_numeric(df['temperature_celsius'],  errors='coerce')
top5_highest = df.nlargest(5, 'temperature_celsius')
# Out:
# /tmp/ipykernel_3558/2968888847.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'temperature_celsius'] = pd.to_numeric(df['temperature_celsius'],  errors='coerce')

# %%
top5_highest
# Out:
#         date      city  temperature_celsius  humidity_percent  wind_speed_kph  \
# 21  23-01-17     Tokyo                 19.3         43.000000       14.352727
# 64  23-01-27    London                 18.1         59.000000        1.000000
# 55  23-01-22  New York                 13.4         58.978723       14.352727
# 34  23-01-25  New York                 12.9         58.978723        5.700000
# 70  23-01-15  New York                 12.2         58.978723       16.500000
#
#    weather_condition  temperature_fahrenheit
# 21             rainy                   66.74
# 64             snowy                   64.58
# 55             snowy                   56.12
# 34             sunny                   55.22
# 70             rainy                   53.96

# %%
with open('outputs/top5_highest_cities.txt', 'w') as file:
    file.write(top5_highest.to_string(index=False))
